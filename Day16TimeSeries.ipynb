# %%
# import
import pandas as pd
import numpy as np

import datetime 
from datetime import datetime, date

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# matplotlib 한글설정
import matplotlib as mpl
import matplotlib.font_manager as fm
mpl.rcParams['axes.unicode_minus'] = False
path = 'C:/Windows/Fonts/malgun.ttf'
font_name = fm.FontProperties(fname=path, size=50).get_name()
plt.rc('font', family=font_name)

# %%
datetime.now()
# Out:
# datetime.datetime(2020, 1, 31, 11, 16, 43, 688888)

# %%
datetime.today()
# Out:
# datetime.datetime(2020, 1, 31, 11, 17, 52, 593830)

# %%
t1 = datetime.now()
t2 = datetime(1970,1,1)
t3 = datetime(1970,12,12, 12, 24, 34)

print(t1)
print(t2)
print(t3)
# Out:
# 2020-01-31 11:20:16.166041
# 1970-01-01 00:00:00
# 1970-12-12 12:24:34

# %%
print(t1 - t2)
diff = t1 - t2
print(diff)
# Out:
# 18292 days, 11:20:16.166041
# 18292 days, 11:20:16.166041

# %%
type(diff)
# Out:
# datetime.timedelta

# %%
ebola = pd.read_csv('./time/country_timeseries.csv')
ebola
# Out:
#            Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0      1/5/2015  289        2776.0            NaN            10030.0
# 1      1/4/2015  288        2775.0            NaN             9780.0
# 2      1/3/2015  287        2769.0         8166.0             9722.0
# 3      1/2/2015  286           NaN         8157.0                NaN
# 4    12/31/2014  284        2730.0         8115.0             9633.0
# ..          ...  ...           ...            ...                ...
# 117   3/27/2014    5         103.0            8.0                6.0
# 118   3/26/2014    4          86.0            NaN                NaN
# 119   3/25/2014    3          86.0            NaN                NaN
# 120   3/24/2014    2          86.0            NaN                NaN
# 121   3/22/2014    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# ...

# %%
ebola.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 18 columns):
# Date                   122 non-null object
# Day                    122 non-null int64
# Cases_Guinea           93 non-null float64
# Cases_Liberia          83 non-null float64
# Cases_SierraLeone      87 non-null float64
# Cases_Nigeria          38 non-null float64
# Cases_Senegal          25 non-null float64
# Cases_UnitedStates     18 non-null float64
# Cases_Spain            16 non-null float64
# Cases_Mali             12 non-null float64
# Deaths_Guinea          92 non-null float64
# Deaths_Liberia         81 non-null float64
# Deaths_SierraLeone     87 non-null float64
# Deaths_Nigeria         38 non-null float64
# Deaths_Senegal         22 non-null float64
# Deaths_UnitedStates    18 non-null float64
# Deaths_Spain           16 non-null float64
# Deaths_Mali            12 non-null float64
# dtypes: float64(16), int64(1), object(1)
# memory usage: 17.3+ KB

# %%
ebola['Date'] = pd.to_datetime(ebola.Date)
ebola.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 18 columns):
# Date                   122 non-null datetime64[ns]
# Day                    122 non-null int64
# Cases_Guinea           93 non-null float64
# Cases_Liberia          83 non-null float64
# Cases_SierraLeone      87 non-null float64
# Cases_Nigeria          38 non-null float64
# Cases_Senegal          25 non-null float64
# Cases_UnitedStates     18 non-null float64
# Cases_Spain            16 non-null float64
# Cases_Mali             12 non-null float64
# Deaths_Guinea          92 non-null float64
# Deaths_Liberia         81 non-null float64
# Deaths_SierraLeone     87 non-null float64
# Deaths_Nigeria         38 non-null float64
# Deaths_Senegal         22 non-null float64
# Deaths_UnitedStates    18 non-null float64
# Deaths_Spain           16 non-null float64
# Deaths_Mali            12 non-null float64
# dtypes: datetime64[ns](1), float64(16), int64(1)
# ...

# %%
test_df1 = pd.DataFrame({'other_day':['01/01/15', '02/01/15', '03/01/15']})
test_df1
# Out:
#   other_day
# 0  01/01/15
# 1  02/01/15
# 2  03/01/15

# %%
test_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 1 columns):
# other_day    3 non-null object
# dtypes: object(1)
# memory usage: 152.0+ bytes

# %%
pd.to_datetime(test_df1.other_day, format='%d/%m/%y')
# Out:
# 0   2015-01-01
# 1   2015-01-02
# 2   2015-01-03
# Name: other_day, dtype: datetime64[ns]

# %%
pd.to_datetime(test_df1.other_day)
# Out:
# 0   2015-01-01
# 1   2015-02-01
# 2   2015-03-01
# Name: other_day, dtype: datetime64[ns]

# %%
test_df1['date1'] = pd.to_datetime(test_df1.other_day, format='%d/%m/%y')
test_df1['date2'] = pd.to_datetime(test_df1.other_day, format='%m/%d/%y')
test_df1['date3'] = pd.to_datetime(test_df1.other_day, format='%y/%m/%d')
test_df1
# Out:
#   other_day      date1      date2      date3
# 0  01/01/15 2015-01-01 2015-01-01 2001-01-15
# 1  02/01/15 2015-01-02 2015-02-01 2002-01-15
# 2  03/01/15 2015-01-03 2015-03-01 2003-01-15

# %%
s = pd.Series(['2018-05-16', '2018-05-17', '2018-05-18'])
s
# Out:
# 0    2018-05-16
# 1    2018-05-17
# 2    2018-05-18
# dtype: object

# %%
s1 = pd.to_datetime(s)
s1
# Out:
# 0   2018-05-16
# 1   2018-05-17
# 2   2018-05-18
# dtype: datetime64[ns]

# %%
s1[0]
# Out:
# Timestamp('2018-05-16 00:00:00')

# %%
print(s1[0].day)
print(s1[0].month)
print(s1[0].year)
# Out:
# 16
# 5
# 2018

# %%
ebola.head()
# Out:
#         Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0 2015-01-05  289        2776.0            NaN            10030.0
# 1 2015-01-04  288        2775.0            NaN             9780.0
# 2 2015-01-03  287        2769.0         8166.0             9722.0
# 3 2015-01-02  286           NaN         8157.0                NaN
# 4 2014-12-31  284        2730.0         8115.0             9633.0
#
#    Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# 0            NaN            NaN                 NaN          NaN         NaN
# 1            NaN            NaN                 NaN          NaN         NaN
# 2            NaN            NaN                 NaN          NaN         NaN
# 3            NaN            NaN                 NaN          NaN         NaN
# 4            NaN            NaN                 NaN          NaN         NaN
#
#    Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  Deaths_Nigeria  \
# ...

# %%
ebola.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 18 columns):
# Date                   122 non-null datetime64[ns]
# Day                    122 non-null int64
# Cases_Guinea           93 non-null float64
# Cases_Liberia          83 non-null float64
# Cases_SierraLeone      87 non-null float64
# Cases_Nigeria          38 non-null float64
# Cases_Senegal          25 non-null float64
# Cases_UnitedStates     18 non-null float64
# Cases_Spain            16 non-null float64
# Cases_Mali             12 non-null float64
# Deaths_Guinea          92 non-null float64
# Deaths_Liberia         81 non-null float64
# Deaths_SierraLeone     87 non-null float64
# Deaths_Nigeria         38 non-null float64
# Deaths_Senegal         22 non-null float64
# Deaths_UnitedStates    18 non-null float64
# Deaths_Spain           16 non-null float64
# Deaths_Mali            12 non-null float64
# dtypes: datetime64[ns](1), float64(16), int64(1)
# ...

# %%
ebola.Date[10].year
# Out:
# 2014

# %%
ebola['year'] = ebola.Date.apply( lambda x: x.year)
ebola['month'] = ebola.Date.apply( lambda x: x.month)
ebola['day'] = ebola.Date.apply( lambda x: x.day)
ebola
# Out:
#           Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0   2015-01-05  289        2776.0            NaN            10030.0
# 1   2015-01-04  288        2775.0            NaN             9780.0
# 2   2015-01-03  287        2769.0         8166.0             9722.0
# 3   2015-01-02  286           NaN         8157.0                NaN
# 4   2014-12-31  284        2730.0         8115.0             9633.0
# ..         ...  ...           ...            ...                ...
# 117 2014-03-27    5         103.0            8.0                6.0
# 118 2014-03-26    4          86.0            NaN                NaN
# 119 2014-03-25    3          86.0            NaN                NaN
# 120 2014-03-24    2          86.0            NaN                NaN
# 121 2014-03-22    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# ...

# %%
ebola.Date.min()
# Out:
# Timestamp('2014-03-22 00:00:00')

# %%
ebola.Date.max()
# Out:
# Timestamp('2015-01-05 00:00:00')

# %%
ebola['outbreak_d'] = ebola.Date - ebola.Date.min() 
ebola.head()
# Out:
#         Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0 2015-01-05  289        2776.0            NaN            10030.0
# 1 2015-01-04  288        2775.0            NaN             9780.0
# 2 2015-01-03  287        2769.0         8166.0             9722.0
# 3 2015-01-02  286           NaN         8157.0                NaN
# 4 2014-12-31  284        2730.0         8115.0             9633.0
#
#    Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# 0            NaN            NaN                 NaN          NaN         NaN
# 1            NaN            NaN                 NaN          NaN         NaN
# 2            NaN            NaN                 NaN          NaN         NaN
# 3            NaN            NaN                 NaN          NaN         NaN
# 4            NaN            NaN                 NaN          NaN         NaN
#
#    ...  Deaths_SierraLeone  Deaths_Nigeria  Deaths_Senegal  \
# ...

# %%
banks = pd.read_csv('./time/banklist.csv', parse_dates=[5,6] )
banks.head()
# Out:
#                                            Bank Name         City  ST   CERT  \
# 0                Washington Federal Bank for Savings      Chicago  IL  30570
# 1    The Farmers and Merchants State Bank of Argonia      Argonia  KS  17719
# 2                                Fayette County Bank   Saint Elmo  IL   1802
# 3  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...    Milwaukee  WI  30003
# 4                                     First NBC Bank  New Orleans  LA  58302
#
#                  Acquiring Institution Closing Date Updated Date
# 0                   Royal Savings Bank   2017-12-15   2017-12-20
# 1                          Conway Bank   2017-10-13   2017-10-20
# 2            United Fidelity Bank, fsb   2017-05-26   2017-07-26
# 3  First-Citizens Bank & Trust Company   2017-05-05   2017-07-26
# 4                         Whitney Bank   2017-04-28   2017-12-05

# %%
banks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555 entries, 0 to 554
# Data columns (total 7 columns):
# Bank Name                555 non-null object
# City                     555 non-null object
# ST                       555 non-null object
# CERT                     555 non-null int64
# Acquiring Institution    555 non-null object
# Closing Date             555 non-null datetime64[ns]
# Updated Date             555 non-null datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(4)
# memory usage: 30.5+ KB

# %%
banks['Closing Date'][0].year
# Out:
# 2017

# %%
banks['Closing Date'][0].quantilerter
# Out:
# 4

# %%
(banks['ClosingQ'], banks['ClosingY']) = (banks['Closing Date'].dt.quarter, banks['Closing Date'].dt.year)
banks.head()
# Out:
#                                            Bank Name         City  ST   CERT  \
# 0                Washington Federal Bank for Savings      Chicago  IL  30570
# 1    The Farmers and Merchants State Bank of Argonia      Argonia  KS  17719
# 2                                Fayette County Bank   Saint Elmo  IL   1802
# 3  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...    Milwaukee  WI  30003
# 4                                     First NBC Bank  New Orleans  LA  58302
#
#                  Acquiring Institution Closing Date Updated Date  ClosingQ  \
# 0                   Royal Savings Bank   2017-12-15   2017-12-20         4
# 1                          Conway Bank   2017-10-13   2017-10-20         4
# 2            United Fidelity Bank, fsb   2017-05-26   2017-07-26         2
# 3  First-Citizens Bank & Trust Company   2017-05-05   2017-07-26         2
# 4                         Whitney Bank   2017-04-28   2017-12-05         2
#
#    ClosingY
# 0      2017
# 1      2017
# ...

# %%
# 연도별 문을닫은 은행의 갯수를 출력해 차트로 만들기
with sns.axes_style('whitegrid'):
    banks.groupby('ClosingY').size().plot(kind='bar')
    plt.xlabel('Year')
    plt.ylabel('Closed')
    plt.title('Closed banks per Year')

# %%
banks.groupby('ClosingQ').size().plot(kind='bar')

# %%
banks.groupby('Closing Date').size().plot()

# %%
banks.groupby('Closing Date').size().idxmax()
# Out:
# Timestamp('2009-10-30 00:00:00')

# %%
tesla = pd.read_csv('./time/tesla_stock_quandl.csv', parse_dates=[0])
tesla.head()
# Out:
#         Date    Open    High     Low   Close      Volume  ExDividend  \
# 0 2018-03-27  304.00  304.27  277.18  279.18  13696168.0         0.0
# 1 2018-03-26  307.34  307.59  291.36  304.18   8324639.0         0.0
# 2 2018-03-23  311.25  311.61  300.45  301.54   6600538.0         0.0
# 3 2018-03-22  313.89  318.82  308.18  309.10   4914307.0         0.0
# 4 2018-03-21  310.25  322.44  310.19  316.53   5927881.0         0.0
#
#    SplitRatio  AdjOpen  AdjHigh  AdjLow  AdjClose   AdjVolume
# 0         1.0   304.00   304.27  277.18    279.18  13696168.0
# 1         1.0   307.34   307.59  291.36    304.18   8324639.0
# 2         1.0   311.25   311.61  300.45    301.54   6600538.0
# 3         1.0   313.89   318.82  308.18    309.10   4914307.0
# 4         1.0   310.25   322.44  310.19    316.53   5927881.0

# %%
tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1949 entries, 0 to 1948
# Data columns (total 13 columns):
# Date          1949 non-null datetime64[ns]
# Open          1949 non-null float64
# High          1949 non-null float64
# Low           1949 non-null float64
# Close         1949 non-null float64
# Volume        1949 non-null float64
# ExDividend    1949 non-null float64
# SplitRatio    1949 non-null float64
# AdjOpen       1949 non-null float64
# AdjHigh       1949 non-null float64
# AdjLow        1949 non-null float64
# AdjClose      1949 non-null float64
# AdjVolume     1949 non-null float64
# dtypes: datetime64[ns](1), float64(12)
# memory usage: 198.1 KB

# %%
# 2010년 7월의 주가데이터
tesla[(tesla.Date >= datetime(2010,7,1))&(tesla.Date<=datetime(2010,7,30))]
# Out:
#            Date     Open   High      Low  Close     Volume  ExDividend  \
# 1926 2010-07-30  20.2000  20.44  19.5500  19.94   426900.0         0.0
# 1927 2010-07-29  20.7700  20.88  20.0000  20.35   616000.0         0.0
# 1928 2010-07-28  20.5500  20.90  20.5100  20.72   467200.0         0.0
# 1929 2010-07-27  20.9100  21.18  20.2600  20.55   619700.0         0.0
# 1930 2010-07-26  21.5000  21.50  20.3000  20.95   922200.0         0.0
# 1931 2010-07-23  21.1900  21.56  21.0600  21.29   653600.0         0.0
# 1932 2010-07-22  20.5000  21.25  20.3700  21.00   957800.0         0.0
# 1933 2010-07-21  20.6600  20.90  19.5000  20.22  1252500.0         0.0
# 1934 2010-07-20  21.8500  21.85  20.0500  20.30  1825300.0         0.0
# 1935 2010-07-19  21.3700  22.25  20.9200  21.91  2486500.0         0.0
# 1936 2010-07-16  20.7000  21.30  20.0500  20.64  2621300.0         0.0
# 1937 2010-07-15  19.9400  21.50  19.0000  19.89  3739800.0         0.0
# ...

# %%
# 2010년 7월의 주가데이터
tesla[(tesla.Date.dt.month==7)&(tesla.Date.dt.year==2010)]
# Out:
#            Date     Open   High      Low  Close     Volume  ExDividend  \
# 1926 2010-07-30  20.2000  20.44  19.5500  19.94   426900.0         0.0
# 1927 2010-07-29  20.7700  20.88  20.0000  20.35   616000.0         0.0
# 1928 2010-07-28  20.5500  20.90  20.5100  20.72   467200.0         0.0
# 1929 2010-07-27  20.9100  21.18  20.2600  20.55   619700.0         0.0
# 1930 2010-07-26  21.5000  21.50  20.3000  20.95   922200.0         0.0
# 1931 2010-07-23  21.1900  21.56  21.0600  21.29   653600.0         0.0
# 1932 2010-07-22  20.5000  21.25  20.3700  21.00   957800.0         0.0
# 1933 2010-07-21  20.6600  20.90  19.5000  20.22  1252500.0         0.0
# 1934 2010-07-20  21.8500  21.85  20.0500  20.30  1825300.0         0.0
# 1935 2010-07-19  21.3700  22.25  20.9200  21.91  2486500.0         0.0
# 1936 2010-07-16  20.7000  21.30  20.0500  20.64  2621300.0         0.0
# 1937 2010-07-15  19.9400  21.50  19.0000  19.89  3739800.0         0.0
# ...

# %%
tesla.tail()
# Out:
#            Date   Open     High    Low  Close      Volume  ExDividend  \
# 
# Out:
#                  Date    Open    High     Low   Close      Volume  ExDividend  \
# Date
# 2018-03-27 2018-03-27  304.00  304.27  277.18  279.18  13696168.0         0.0
# 2018-03-26 2018-03-26  307.34  307.59  291.36  304.18   8324639.0         0.0
# 2018-03-23 2018-03-23  311.25  311.61  300.45  301.54   6600538.0         0.0
# 2018-03-22 2018-03-22  313.89  318.82  308.18  309.10   4914307.0         0.0
# 2018-03-21 2018-03-21  310.25  322.44  310.19  316.53   5927881.0         0.0
#
#             SplitRatio  AdjOpen  AdjHigh  AdjLow  AdjClose   AdjVolume  \
# Date
# 2018-03-27         1.0   304.00   304.27  277.18    279.18  13696168.0
# 2018-03-26         1.0   307.34   307.59  291.36    304.18   8324639.0
# 2018-03-23         1.0   311.25   311.61  300.45    301.54   6600538.0
# 2018-03-22         1.0   313.89   318.82  308.18    309.10   4914307.0
# 2018-03-21         1.0   310.25   322.44  310.19    316.53   5927881.0
#
#               refdat
# Date
# 2018-03-27 2828 days
# ...

# %%
tesla.tail()
# Out:
#                  Date   Open     High    Low  Close      Volume  ExDividend  \
# Date
# 2010-07-06 2010-07-06  20.00  20.0000  15.83  16.11   6866900.0         0.0
# 2010-07-02 2010-07-02  23.00  23.1000  18.71  19.20   5139800.0         0.0
# 2010-07-01 2010-07-01  25.00  25.9200  20.27  21.96   8218800.0         0.0
# 2010-06-30 2010-06-30  25.79  30.4192  23.30  23.83  17187100.0         0.0
# 2010-06-29 2010-06-29  19.00  25.0000  17.54  23.89  18766300.0         0.0
#
#             SplitRatio  AdjOpen  AdjHigh  AdjLow  AdjClose   AdjVolume refdat
# Date
# 2010-07-06         1.0    20.00  20.0000   15.83     16.11   6866900.0 7 days
# 2010-07-02         1.0    23.00  23.1000   18.71     19.20   5139800.0 3 days
# 2010-07-01         1.0    25.00  25.9200   20.27     21.96   8218800.0 2 days
# 2010-06-30         1.0    25.79  30.4192   23.30     23.83  17187100.0 1 days
# 2010-06-29         1.0    19.00  25.0000   17.54     23.89  18766300.0 0 days

# %%
tesla['2015-09':'2015-06']
# Out:
#                  Date    Open    High     Low   Close     Volume  ExDividend  \
# Date
# 2015-09-30 2015-09-30  252.00  252.40  242.34  248.40  4879816.0         0.0
# 2015-09-29 2015-09-29  250.46  254.73  245.46  246.65  3703154.0         0.0
# 2015-09-28 2015-09-28  257.35  259.79  246.61  248.43  4881802.0         0.0
# 2015-09-25 2015-09-25  266.61  266.91  256.15  256.91  3773392.0         0.0
# 2015-09-24 2015-09-24  259.53  263.45  256.21  263.12  3448191.0         0.0
# ...               ...     ...     ...     ...     ...        ...         ...
# 2015-06-05 2015-06-05  246.00  249.70  245.68  249.14  3022026.0         0.0
# 2015-06-04 2015-06-04  247.50  249.30  245.71  245.92  2453615.0         0.0
# 2015-06-03 2015-06-03  248.20  250.72  247.01  248.99  1781505.0         0.0
# 2015-06-02 2015-06-02  248.92  249.40  246.30  248.35  2134809.0         0.0
# 2015-06-01 2015-06-01  251.41  251.60  247.47  249.45  2505057.0         0.0
#
# ...

# %%
ebola = pd.read_csv('./time/country_timeseries.csv')
ebola5 = ebola.head()
ebola5
# Out:
#          Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0    1/5/2015  289        2776.0            NaN            10030.0
# 1    1/4/2015  288        2775.0            NaN             9780.0
# 2    1/3/2015  287        2769.0         8166.0             9722.0
# 3    1/2/2015  286           NaN         8157.0                NaN
# 4  12/31/2014  284        2730.0         8115.0             9633.0
#
#    Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# 0            NaN            NaN                 NaN          NaN         NaN
# 1            NaN            NaN                 NaN          NaN         NaN
# 2            NaN            NaN                 NaN          NaN         NaN
# 3            NaN            NaN                 NaN          NaN         NaN
# 4            NaN            NaN                 NaN          NaN         NaN
#
#    Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  Deaths_Nigeria  \
# ...

# %%
ebola5.index =  ebola5['Date']
ebola5
# Out:
#                   Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# Date
# 1/5/2015      1/5/2015  289        2776.0            NaN            10030.0
# 1/4/2015      1/4/2015  288        2775.0            NaN             9780.0
# 1/3/2015      1/3/2015  287        2769.0         8166.0             9722.0
# 1/2/2015      1/2/2015  286           NaN         8157.0                NaN
# 12/31/2014  12/31/2014  284        2730.0         8115.0             9633.0
#
#             Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# Date
# 1/5/2015              NaN            NaN                 NaN          NaN
# 1/4/2015              NaN            NaN                 NaN          NaN
# 1/3/2015              NaN            NaN                 NaN          NaN
# 1/2/2015              NaN            NaN                 NaN          NaN
# 12/31/2014            NaN            NaN                 NaN          NaN
#
# ...

# %%
head_range = pd.date_range(start='2014-12-31', end='2015-01-05')
head_range
# Out:
# DatetimeIndex(['2014-12-31', '2015-01-01', '2015-01-02', '2015-01-03',
#                '2015-01-04', '2015-01-05'],
#               dtype='datetime64[ns]', freq='D')

# %%
ebola5.reindex(head_range)
# Out:
#            Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 2014-12-31  NaN  NaN           NaN            NaN                NaN
# 2015-01-01  NaN  NaN           NaN            NaN                NaN
# 2015-01-02  NaN  NaN           NaN            NaN                NaN
# 2015-01-03  NaN  NaN           NaN            NaN                NaN
# 2015-01-04  NaN  NaN           NaN            NaN                NaN
# 2015-01-05  NaN  NaN           NaN            NaN                NaN
#
#             Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 2014-12-31            NaN            NaN                 NaN          NaN
# 2015-01-01            NaN            NaN                 NaN          NaN
# 2015-01-02            NaN            NaN                 NaN          NaN
# 2015-01-03            NaN            NaN                 NaN          NaN
# 2015-01-04            NaN            NaN                 NaN          NaN
# ...

# %%
 pd.date_range('2017-01-01','2017-01-07', freq='B')
# Out:
# DatetimeIndex(['2017-01-02', '2017-01-03', '2017-01-04', '2017-01-05',
#                '2017-01-06'],
#               dtype='datetime64[ns]', freq='B')

# %%
ebola.index = ebola.Date
fig, ax = plt.subplots()
ax = ebola[::-1].iloc[0:, 10:].plot(ax=ax)
ax.legend(fontsize=7, loc=2, borderaxespad=0)
plt.show()
