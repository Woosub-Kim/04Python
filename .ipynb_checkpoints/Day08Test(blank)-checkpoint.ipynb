# %% [markdown]
# ### Test

# %%
txt1 = 'A tale that was not right'
#String

# ale이 출력..


# A tale이 출력


# not출력


# txt1을 대문자로 전환


# txt1을 소문자로 전환


# 'o'의 갯수


# 'o'의 인덱스


# txt1의 길이


# space로 나누어서 List에 담기


# tale을 story로 바꾸세요


# txt1안에 right가 있는지 확인하세요

#List

sol = ['태양', '수성', '금성', '지구', '화성', '목성', '지구']

# sol에서 ['수성', 금성]을 출력


# sol에서 '지구'위치 인덱스 출력


# sol에서 '화성'을 '해왕성'으로 수정


# sol에서 '수성'자리에 '명왕성' 삽입


# sol 맨끝에 '토성'삽입


# sol 맨끝요소 삭제하고 리턴


# sol에서 '금성'제거


# sol에서 1~3인덱스 제거


# sol에서 인덱스 2번 요소 제거


# sol을 오름차순으로 정렬


# sol을 내림차순으로 정렬


# sol에서 '만리장성'이 있는지 확인


# sol1을 3반복


# sol의 길이를 리턴


# sol에서 '지구'의 갯수 확인


# sol의 모든요소를 지우기


# 리스트 sol 완전 삭제

#Tuple

myTuple = ('tuple', (1,2,3), [4,5,6,7,8],'7', '8', '9')

# 'tuple'을 출력하세요


# 3을 출력하세요


# 4,5를 출력하세요

# [4,5,6]을 출력하세요


# myTuple의 길이를 리턴하세요


# myTuple에서 '7'이 있는지 확인하기


# myTuple에서 '7'의 인덱스 출력하기


# myTuple에서 '7'의 갯수 출력하기


# myTuple 2번 인덱스를 출력하시오


# myTuple 2번 인덱스의 최댓값 출력하기


# myTuple 2번 인덱스의 최솟값 출력하기


# myTuple 2번 인덱스의 합을 출력하기


# myTuple 2번 인덱스의 평균 출력하기


# myTuple 2번 인덱스 내림차순으로 정렬해서 출력하기

#Set
# 원소가 없는 set을 만드세요


# 원소 'sky'와 'earth'를 추가하세요


# (1,2) 두 원소를 추가하세요


# 'sky'를 삭재하세요


# 다음의 집합에서
A = {1,2,3,4,5,6}
B = {1,2,3,7,8,9}
C ={1,2,3}

# A,B 두 집합의 합집합을 출력


# A의 B에 대한 집합의 차집합을 출력


# A,B 두 집합의 교집합을 구하세요


# A,B의 대칭차집합


# C가 A의 부분집합인지 확인


# A가 C를 포함하는지 확인


# B의 길이를 출격


# B의 최댓값 출력


# B의 최솟값 출력


# B의 합을 출력


# B의 평균을 출력


# B를 내림차순으로 정렬


# B에 정수 5가 포함되어 있는지 확인하기

# Dictionary

# 'mydict'라는 빈 dictionary를 만드시오


# 'red':1, 'blue':3, 'green':4 세 요소를 mydict에 추가하시오


# mydict에 key에 'blue'기 있는지 확인하시오


# mydict의 길이를 출력하시오


# mydict에서 'red'의 value를 출력하시오


# mydict에서 'red'의 value를 10으로 변경하시오


# mydict에서 key값만 출력하시오


# mydict에서 value값만 출력하시오


# mydict에서 key와 value를 tuple로 출력하시오


# mydict을 key기준으로 정렬하시오


# mydict을 value기준으로 정렬하시오


# key 'blue'를 삭제하시오


# key 'blue'의 값을 오류없이 출력하시오


# mydict에 key 'pink'값을 출력하되 없으면 20추가


# mydict value에 20이 있는지 확인


# mydict에 'yellow':30을 추가하시오


# mydict과 yourdict = {'파랑':50, '빨강':70}을 합하시오

# if
# input()함수로 점수를 입력받아 학점을 출력하는 코드  

# 가위바위보 구현하기

# 정수를 입력받아 짝수인지 홀수인지 판단하기

names = {'mary':1520, 'tom':5214, 'park':5478, 'sams':5478}
#이름을 입력받은 후 names dict에 있으면 값 출력하고 없으면 새로운 값과 함께 dict에 추가

# Loop

# text = 'python is fun' 중에서 문자를 대문자로 변환해서 출력하세요

# 1~20까지 출력하세요

# 1~20까지 짝수만 출력하세요

# for문과 while문을 각각 활용해서 1~10까지 합을 구하세요

# 1~10사이의 정수중에서 짝수만 리스트에 담으세요 for문으로

# 위 문제를 ListComprehension으로 구현하시오

# computational thinking에서 모음만 리스트에 담으세요

# 점수를 5회 입력받은 후에 평균을 출력하시오

# text = 'hello world'에서 각 문자를 인덱스와 함께 tuple로 출력하시오

#1~50까지의 수에서 짝수함과 홀수합으로 각각 출력하세요

# File

# mytest.txt파일을 열어서 아래의 텍스트를 작성하세요
"""
'hello python'
'python progamming'
'python world'
'bigdata'
'artificial intelligence'
"""

# mytest파일을 열어서 4가지 방법으로 출력하세요

# mytest파일을 열어서 아래와 같이 출력하세요
"""
1,'hello python'
2,'python progamming'
3,'python world'
4,'bigdata'
5,'artificial intelligence'
"""

#'mytest.txt' 파일을 with구문을 활용해서 읽어서 출력하시오

# test_list = ['a', 'b', 'c'] pickle파일로 저장하세요

# 위에서 저장한 피클파일을 읽어 출력하세요

# %%
try:
    c = input('알파벳 하나를 입력하세요')
    if c in range(ord(a), ord(z)+1):
        print('소문자입력')
    elif c in range(ord(A), ord(Z)+1):
        print('대문자입력')
    else:
        raise exception
except:
    print('알파벳이 아님')
# Out:
# 알파벳 하나를 입력하세요5
# 알파벳이 아님
