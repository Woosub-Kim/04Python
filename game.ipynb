# %%
import numpy as np
def rcp(num):
    if num == 1: return '가위'
    elif num==2: return '바위'
    else: return '보'
def rcpprinter(u,c):
    print('사용자의 선택:{}'.format(rcp(u)))
    print('컴퓨터의 선택:{}'.format(rcp(c)))
coin = 1
while True:
    if coin==1:
        try:
            coin = 6 if input('계속 하려면 0을 누르세요. 그만하려면 아무 키를 누르세요.')=='0' else 0
        except:
            print('다시 입력하세요')
    if coin==0: break
    while True:
        try:
            user = int(input('1: 가위, 2: 바위, 3: 보'))
            if user not in (1,2,3):
                print('??')
                raise Exception
            break
        except:
            print('1,2,3 중 입력하세요')
    computer = np.random.choice([1,2,3])
    print(user, computer)
    if user==computer:
        rcpprinter(user,computer)
        print('비김')
    elif (user, computer) in [(1,3),(2,1),(3,2)]:
        rcpprinter(user,computer)
        print('당신의 승리')
    else:
        rcpprinter(user,computer)
        print('컴퓨터의 승리')
    coin -= 1
# Out:
# 계속 하려면 0을 누르세요. 그만하려면 아무 키를 누르세요.0
# 1: 가위, 2: 바위, 3: 보2
# 2 3
# 사용자의 선택:바위
# 컴퓨터의 선택:보
# 컴퓨터의 승리
# 1: 가위, 2: 바위, 3: 보2
# 2 1
# 사용자의 선택:바위
# 컴퓨터의 선택:가위
# 당신의 승리
# 1: 가위, 2: 바위, 3: 보1
# 1 3
# 사용자의 선택:가위
# 컴퓨터의 선택:보
# 당신의 승리
# 1: 가위, 2: 바위, 3: 보1
# 1 1
# 사용자의 선택:가위
# 컴퓨터의 선택:가위
# 비김
# 1: 가위, 2: 바위, 3: 보3
# 3 1
# 사용자의 선택:보
# 컴퓨터의 선택:가위
# 컴퓨터의 승리
# 계속 하려면 0을 누르세요. 그만하려면 아무 키를 누르세요.0
# 1: 가위, 2: 바위, 3: 보3
# 3 1
# 사용자의 선택:보
# 컴퓨터의 선택:가위
# 컴퓨터의 승리
# 1: 가위, 2: 바위, 3: 보0
# ??
# 1,2,3 중 입력하세요
# 1: 가위, 2: 바위, 3: 보1
# 1 2
# 사용자의 선택:가위
# 컴퓨터의 선택:바위
# 컴퓨터의 승리
# 1: 가위, 2: 바위, 3: 보1
# 1 1
# 사용자의 선택:가위
# 컴퓨터의 선택:가위
# 비김
# 1: 가위, 2: 바위, 3: 보1
# 1 2
# 사용자의 선택:가위
# 컴퓨터의 선택:바위
# 컴퓨터의 승리
# 1: 가위, 2: 바위, 3: 보1
# 1 1
# 사용자의 선택:가위
# 컴퓨터의 선택:가위
# 비김
# 계속 하려면 0을 누르세요. 그만하려면 아무 키를 누르세요.3

# %%
while True:
    print('무간지옥')
    ip = input('0을 누르면 종료')
    if ip == '0':
        print('잘가라')
        break
    print('영원히 고통받지')
# Out:
# 무간지옥
# 0을 누르면 종료
# 영원히 고통받지
# 무간지옥
# 0을 누르면 종료9
# 영원히 고통받지
# 무간지옥
# 0을 누르면 종료8
# 영원히 고통받지
# 무간지옥
# 0을 누르면 종료7
# 영원히 고통받지
# 무간지옥
# 0을 누르면 종료6
# 영원히 고통받지
# 무간지옥
# 0을 누르면 종료5
# 영원히 고통받지
# 무간지옥
# 0을 누르면 종료4
# 영원히 고통받지
# 무간지옥
# 0을 누르면 종료3
# 영원히 고통받지
# 무간지옥
# 0을 누르면 종료2
# 영원히 고통받지
# 무간지옥
# 0을 누르면 종료1
# 영원히 고통받지
# 무간지옥
# 0을 누르면 종료0
# 잘가라

# %%
import numpy as np
while True:
    print('당신은 무인도에 갇혔습니다. 만약 주사위를 두번 굴려 같은 숫자가 나오면 빠져나갈 수 있습니다.')
    u = input('주사위를 던지기 위해 아무거나 입력하세요')
    dice1 = np.random.choice([1,2,3,4,5,6])
    print('첫 주사위: ',dice1)
    dice2 = np.random.choice([1,2,3,4,5,6])
    print('둘째 주사위: ',dice2)
    if dice1 == dice2:
        print('탈출성공')
        break
    else:
        print('꽝!')
# Out:
# 당신은 무인도에 갇혔습니다. 만약 주사위를 두번 굴려 같은 숫자가 나오면 빠져나갈 수 있습니다.
# 주사위를 던지기 위해 아무거나 입력하세요1
# 첫 주사위:  6
# 둘째 주사위:  5
# 꽝!
# 당신은 무인도에 갇혔습니다. 만약 주사위를 두번 굴려 같은 숫자가 나오면 빠져나갈 수 있습니다.
# 주사위를 던지기 위해 아무거나 입력하세요1
# 첫 주사위:  4
# 둘째 주사위:  2
# 꽝!
# 당신은 무인도에 갇혔습니다. 만약 주사위를 두번 굴려 같은 숫자가 나오면 빠져나갈 수 있습니다.
# 주사위를 던지기 위해 아무거나 입력하세요2
# 첫 주사위:  2
# 둘째 주사위:  6
# 꽝!
# 당신은 무인도에 갇혔습니다. 만약 주사위를 두번 굴려 같은 숫자가 나오면 빠져나갈 수 있습니다.
# 주사위를 던지기 위해 아무거나 입력하세요2
# 첫 주사위:  6
# 둘째 주사위:  3
# 꽝!
# 당신은 무인도에 갇혔습니다. 만약 주사위를 두번 굴려 같은 숫자가 나오면 빠져나갈 수 있습니다.
# 주사위를 던지기 위해 아무거나 입력하세요2
# 첫 주사위:  5
# 둘째 주사위:  3
# 꽝!
# 당신은 무인도에 갇혔습니다. 만약 주사위를 두번 굴려 같은 숫자가 나오면 빠져나갈 수 있습니다.
# 주사위를 던지기 위해 아무거나 입력하세요2
# 첫 주사위:  1
# 둘째 주사위:  1
# 탈출성공

# %%
import numpy as np
money = 10000
while True:
    print('야바위꾼과 내기를 할 수 있습니다')
    ybw = np.random.choice([1,2,3])
    while True:
        try:
            you = int(input('1,2,3중 하나를 선택하세요'))
            if you in (1,2,3):
                print('당신의 선택: ', you)
                break
            else:
                raise Exception
        except:
            print('1,2,3중에 선택하세요')
    while True:
        try:
            print('당신의 한도', money)
            bet = int(input('당신이 가진 금액 한도에서 베팅하세요(100원 단위)'))
            if (bet <= money)and(bet%100==0):
                money -= bet
                print('당신의 베팅: ',bet)
                print('당신의 잔액', money)
                break
            else:
                raise Exception
        except:
            print('당신이 가진 금액 한도내에서 숫자로 입력하세요(100 단위)')
    print('당신의 선택: ', you)
    print('야바위 선택: ', ybw)
    if you == ybw:
        money += 2*bet
    print('당신의 잔액', money)
    if money <= 0:
        print('잔액이 0이 되어 야바위판에서 쫓겨났습니다')
        break
    keepgoing = input('계속하시려면 0을 입력하세요')
    if keepgoing != '0':
        break
# Out:
# 야바위꾼과 내기를 할 수 있습니다
# 1,2,3중 하나를 선택하세요3
# 당신의 선택:  3
# 당신의 한도 10000
# 당신이 가진 금액 한도에서 베팅하세요(100원 단위)10000
# 당신의 베팅:  10000
# 당신의 잔액 0
# 당신의 선택:  3
# 야바위 선택:  3
# 당신의 잔액 20000
# 계속하시려면 0을 입력하세요0
# 야바위꾼과 내기를 할 수 있습니다
# 1,2,3중 하나를 선택하세요2
# 당신의 선택:  2
# 당신의 한도 20000
# 당신이 가진 금액 한도에서 베팅하세요(100원 단위)5000
# 당신의 베팅:  5000
# 당신의 잔액 15000
# 당신의 선택:  2
# 야바위 선택:  2
# 당신의 잔액 25000
# 계속하시려면 0을 입력하세요0
# 야바위꾼과 내기를 할 수 있습니다
# 1,2,3중 하나를 선택하세요3
# 당신의 선택:  3
# 당신의 한도 25000
# 당신이 가진 금액 한도에서 베팅하세요(100원 단위)2000
# 당신의 베팅:  2000
# 당신의 잔액 23000
# 당신의 선택:  3
# 야바위 선택:  2
# 당신의 잔액 23000
# 계속하시려면 0을 입력하세요0
# 야바위꾼과 내기를 할 수 있습니다
# 1,2,3중 하나를 선택하세요1
# 당신의 선택:  1
# 당신의 한도 23000
# 당신이 가진 금액 한도에서 베팅하세요(100원 단위)3000
# 당신의 베팅:  3000
# 당신의 잔액 20000
# 당신의 선택:  1
# 야바위 선택:  3
# 당신의 잔액 20000
# 계속하시려면 0을 입력하세요0
# 야바위꾼과 내기를 할 수 있습니다
# 1,2,3중 하나를 선택하세요1
# 당신의 선택:  1
# 당신의 한도 20000
# 당신이 가진 금액 한도에서 베팅하세요(100원 단위)5000
# 당신의 베팅:  5000
# 당신의 잔액 15000
# 당신의 선택:  1
# 야바위 선택:  1
# 당신의 잔액 25000
# 계속하시려면 0을 입력하세요0
# 야바위꾼과 내기를 할 수 있습니다
# 1,2,3중 하나를 선택하세요1
# 당신의 선택:  1
# 당신의 한도 25000
# 당신이 가진 금액 한도에서 베팅하세요(100원 단위)1000
# 당신의 베팅:  1000
# 당신의 잔액 24000
# 당신의 선택:  1
# 야바위 선택:  2
# 당신의 잔액 24000
# 계속하시려면 0을 입력하세요0
# 야바위꾼과 내기를 할 수 있습니다
# 1,2,3중 하나를 선택하세요1
# 당신의 선택:  1
# 당신의 한도 24000
# 당신이 가진 금액 한도에서 베팅하세요(100원 단위)1000
# 당신의 베팅:  1000
# 당신의 잔액 23000
# 당신의 선택:  1
# 야바위 선택:  1
# 당신의 잔액 25000
# 계속하시려면 0을 입력하세요0
# 야바위꾼과 내기를 할 수 있습니다
# 1,2,3중 하나를 선택하세요3
# 당신의 선택:  3
# 당신의 한도 25000
# 당신이 가진 금액 한도에서 베팅하세요(100원 단위)3000
# 당신의 베팅:  3000
# 당신의 잔액 22000
# 당신의 선택:  3
# 야바위 선택:  3
# 당신의 잔액 28000
# 계속하시려면 0을 입력하세요3

# %%
import numpy as np
deck = []
you = []
com = []
for shape in ['Spade ', 'Club  ', 'Diamon', 'Heart ']:
    for num in [2,3,4,5,6,7,8,9,10,'A', 'J', 'Q', 'K']:
        card = shape[0]+str(num)
        exec(card+'=(shape, num)')
        exec('deck.append('+card+')')
print(len(deck))      
for i in range(7):
    you.append(deck.pop(np.random.choice(range(len(deck)))))
print(len(deck))      
for i in range(7):
    com.append(deck.pop(np.random.choice(range(len(deck)))))
print(len(deck))      
print('당신의 패  : ',you)
print('컴퓨터의 패: ',com)
# Out:
# 52
# 45
# 38
# 당신의 패  :  [('Club  ', 3), ('Spade ', 10), ('Diamon', 5), ('Spade ', 2), ('Spade ', 'Q'), ('Heart ', 2), ('Club  ', 5)]
# 컴퓨터의 패:  [('Diamon', 'J'), ('Diamon', 'K'), ('Club  ', 9), ('Heart ', 10), ('Club  ', 'J'), ('Heart ', 3), ('Diamon', 7)]

# %% [markdown]
# 1. 로얄 플러쉬(Royal Flush a.k.a 로티플)
# 같은 무늬의 카드로 10,J,Q,K,A를 가지고 있으면 메이드
#
# 2. 스트레이트 플러쉬(Straight Flush a.k.a 스티플)
# 같은 무늬로 5장의 연속된 카드를 가지고 있으면 메이드
#
# 3. 포카드(Four of a kind)
# 같은 숫자의 카드를 4장 가지고 있으면 메이드
#
# 4. 풀하우스(Full House)
# 트리플과 함께 하나의 페어를 가지고 있으면 메이드
# 같은 랭킹일 경우 트리플의 숫자가 높은 플레이어가 승리
#
# 5. 플러쉬(Flush)
# 같은 무늬의 카드를 5장 가지고 있으면 메이드
# 같은 랭킹일 경우 가장 높은 숫자를 보유한 플레이어가 승리
#
# 6. 스트레이트(Straight)
# 연속된 5장의 카드를 가지고 있으면 메이드
# A(Ace)의 경우는 10,J,Q,K,A와 A,2,3,4,5가 가능
# 전자의 경우 스트레이트에서 가장 높은 등급이고, 후자의 경우가 가장 낮은 등급
#
# 7. 쓰리 오브 어 카인드(Three of a kind a.k.a 트리플)
# 같은 숫자의 카드를 3장 가지고 있으면 메이드
#
# 8. 투페어(Two Pair)
# 같은 숫자의 카드 2장을 2개 보유하고 있으면 메이드
#
# 9. 원페어(One Pair)
# 같은 숫자의 카드 2장을 1개 보유하고 있으면 메이드
#
# 10. 하이카드(High Card)
# 아무런 페어가 없이 가지고 있는 숫자중 가장 높은 수치의 카드

# %%
# Out:
# 3
